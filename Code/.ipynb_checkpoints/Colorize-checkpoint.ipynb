# %%
import tensorflow as tf
#Vers. 0.12.1
#print(tf.__version__)
import sys
#Should be above 3.5
#print (sys.versio£n)     

import cv2
import numpy as np
import os
import glob
import pickle

import matplotlib.image as mpimg
from skimage import color

import random

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)

from Helpers import get_files, load_image, separate_imgs, get_next_batch_from_disk_RGB, get_next_batch_from_disk_RGB_Nocrop, get_next_batch_from_disk_HSV, get_next_batch_from_disk_Nocrop_HSV, get_next_batch_from_disk_RGB_Gaussian

# %% [markdown]
# # Colorize

# %%
def colorize_TF(gray_images):
    with tf.Session() as sess:
        model_path = "./recent/model.ckpt"
        save_dir = 'recent'

        new_saver = tf.train.import_meta_graph(save_dir + "/model.ckpt.meta")
        new_saver.restore(sess, save_dir + '/model.ckpt')

        # tf.get_collection() returns a list. In this example we only want the
        # first one.
        colored_images = tf.get_collection('color_image')[0]

        images = np.array(gray_images)
        
        return sess.run(colored_images, feed_dict={"x:0": images, "keep_prob:0" :1, "is_training:0" : False},)

# %%
images_list = get_files("../Data/Extracted/*", '*.jpg')
batch_size = 15

gray, img = get_next_batch_from_disk_RGB_Gaussian(images_list, batch_size, crop_size=224)

colored = colorize_TF(gray)

# %%
index = 1
r = img[index][..., 0]
g = img[index][..., 1]
b = img[index][..., 2]

plt.imshow(np.dstack((r,g,b)))

# %%
plt.imshow(gray[index][..., 0], cmap="gray")

# %%
r2 = colored[index][..., 0]
g2 = colored[index][..., 1]
b2 = colored[index][..., 2]

plt.imshow(np.dstack((r2,g2,b2)))

# %%
images_list = get_files("../Data/Extracted/Pres/", '*.jpg')
len(images_list)


gray, img = get_next_batch_from_disk_RGB_Gaussian(images_list, batch_size, crop_size=224)

colored = colorize_TF(gray)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\google\protobuf\internal\containers.py in __getitem__(self, key)
#     552     try:
# --> 553       return self._values[key]
#     554     except KeyError:
#
# KeyError: 'T'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-6186c03db9f7> in <module>()
#       6 gray, img = get_next_batch_from_disk_RGB_Gaussian(images_list, batch_size, crop_size=224)
#       7
# ----> 8 colored = colorize_TF(gray)
#
# <ipython-input-31-1e6b92734da9> in colorize_TF(gray_images)
#       5
#       6         new_saver = tf.train.import_meta_graph(save_dir + "/model.ckpt.meta")
# ----> 7         new_saver.restore(sess, save_dir + '/model.ckpt')
#       8
# ...
