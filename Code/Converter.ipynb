# %%
from PIL import Image

import os
import glob
from Helpers import get_files

# %%
def get_files(path, ext):
    #"*.mp4"
    #"..\Data\"
    return glob.glob(os.path.join(path, ext))

# %%
images_list = get_files("../Data/trees/", '*.ppm')

a = '..'
b = 'Data'
c = 'trees'

path = glob.glob(".." + os.sep + "Data" + os.sep + "tress")


len(path)
images_list
# Out:
# ['../Data/trees\\cps201004281214.ppm',
#  '../Data/trees\\cps201004281239.ppm',
#  '../Data/trees\\cps201004281281.ppm',
#  '../Data/trees\\cps201004281289.ppm',
#  '../Data/trees\\cps201004281295.ppm',
#  '../Data/trees\\cps201004281297.ppm',
#  '../Data/trees\\cps201004281302.ppm',
#  '../Data/trees\\cps201004281307.ppm',
#  '../Data/trees\\cps201004281308.ppm',
#  '../Data/trees\\cps201004281313.ppm',
#  '../Data/trees\\cps201004281316.ppm',
#  '../Data/trees\\cps201004281318.ppm',
#  '../Data/trees\\cps201004281323.ppm',
#  '../Data/trees\\cps201004281325.ppm',
#  '../Data/trees\\cps201004281327.ppm',
#  '../Data/trees\\cps201004281329.ppm',
#  '../Data/trees\\cps201004281330.ppm',
#  '../Data/trees\\cps201004281332.ppm',
#  '../Data/trees\\cps201004281333.ppm',
#  '../Data/trees\\cps201004281334.ppm',
#  '../Data/trees\\cps201004281335.ppm',
#  '../Data/trees\\cps201004281337.ppm',
#  '../Data/trees\\cps201004281338.ppm',
#  '../Data/trees\\cps201004281344.ppm',
# ...

# %%
i = 0
for f in path:
    i = i+1
    im = Image.open(f)
    im.save("tree" + i + ".jpg")
